# %% [markdown]
# Colab is making it easier than ever to integrate powerful Generative AI capabilities into your projects. We are launching public preview for a simple and intuitive Python library (google.colab.ai) to access state-of-the-art language models directly within Colab environments. All users have free access to most popular LLMs, while paid users have access to a wider selection of models. This means users can spend less time on configuration and set up and more time bringing their ideas to life. With just a few lines of code, you can now perform a variety of tasks:
# - Generate text
# - Translate languages
# - Write creative content
# - Categorize text
#
# Happy Coding!
#
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb)

# %%
# @title List available models
from google.colab import ai

ai.list_models()
# Out:
# ['google/gemini-2.0-flash',
#  'google/gemini-2.0-flash-lite',
#  'google/gemini-2.5-flash',
#  'google/gemini-2.5-flash-lite',
#  'google/gemini-2.5-pro',
#  'google/gemini-3-pro-preview',
#  'google/gemma-3-12b',
#  'google/gemma-3-1b',
#  'google/gemma-3-27b',
#  'google/gemma-3-4b']

# %% [markdown]
# Choosing a Model
# The model names give you a hint about their capabilities and intended use:
#
# Pro: These are the most capable models, ideal for complex reasoning, creative tasks, and detailed analysis.
#
# Flash: These models are optimized for high speed and efficiency, making them great for summarization, chat applications, and tasks requiring rapid responses.
#
# Gemma: These are lightweight, open-weight models suitable for a variety of text generation tasks and are great for experimentation.

# %%
# @title Simple batch generation example
# Only text-to-text input/output is supported
from google.colab import ai

response = ai.generate_text("What is the capital of France?")
print(response)
# Out:
# The capital of France is **Paris**.

# %%
# @title Choose a different model
from google.colab import ai

response = ai.generate_text("What is the capital of England", model_name='google/gemini-3-pro-preview')
print(response)
# Out:
# The capital of England is **London**.

# %% [markdown]
# For longer text generations, you can stream the response. This displays the output token by token as it's generated, rather than waiting for the entire response to complete. This provides a more interactive and responsive experience. To enable this, simply set stream=True.

# %%
# @title Simple streaming example
from google.colab import ai

stream = ai.generate_text("Tell me a short story.", stream=True)
for text in stream:
  print(text, end='')
# Out:
# Elara lived on the fifth floor of an old brick building, a silent guardian of dusty books in the city library. Her life was a carefully folded paper crane – precise, predictable, and beautiful in its quiet way. Every morning, she brewed Earl Grey, read the same column in the newspaper, and then walked the familiar route to work, her sensible shoes clicking a steady rhythm on the pavement.
#
# One Tuesday, however, the rhythm skipped a beat. As she watered her small, hardy basil plant on the fire escape balcony – the only patch of green she nurtured – she noticed it. Nestled among the gray concrete and wilting geraniums was a flower.
#
# It wasn't just *a* flower. It was unlike anything she had ever seen. Its petals were the colour of a midnight sky, but they shimmered with an inner light, a soft, pulsating glow that seemed to breathe. From its centre, delicate tendrils, fine as spun silver, unfurled, occasionally catching the breeze like tiny, living antennae. It emitted a faint, sweet scent, like jasmine mixed with a summer rain shower and something ancient, something wild.
#
# Elara, usually so methodical, simply stared. She forgot her tea, forgot the newspaper, forgot even the time. The flower hummed, a low, barely perceptible vibration that resonated not in her ears, but in her chest.
#
# Cautiously, she reached out. Her fingertip brushed a petal. A jolt, not of electricity, but of pure wonder, shot through her. Images flooded her mind: a forgotten childhood swing, the taste of her grandmother’s cookies, the laughter of a stranger on a sunny day. It was as if the flower was singing a symphony of forgotten joys, awakening dormant senses within her.
#
# Days turned into a week. Elara still went to work, still shelved books, but her routine now included long, mesmerized hours on the fire escape. She talked to the flower, whispering her thoughts, her quiet dreams. It didn't speak back, but its glow intensified, its hum deepened, and Elara felt an undeniable connection, a warmth she hadn't known she was missing.
#
# One evening, as the city lights began to twinkle below, she watched a moth flutter tentatively towards the glowing bloom. It hovered, captivated, then landed gently on a silver tendril. For a moment, the moth pulsed with the same soft light as the flower, then took flight, leaving a faint trail of luminescence in its wake as it ascended into the vast, dark sky.
#
# Elara smiled, a genuine, expansive smile that crinkled the corners of her eyes. The flower hadn't changed her life in any grand, dramatic way. It hadn't granted wishes or solved her problems. But it had opened a window in her soul, reminding her that even in the most predictable of lives, amidst the concrete and the routine, there was always room for magic, always room for unexpected beauty, waiting to bloom. And sometimes, all it took was a single, luminous petal to make you see it.

# %%
#@title Text formatting setup
#code is not necessary for colab.ai, but is useful in fomatting text chunks
import sys

class LineWrapper:
    def __init__(self, max_length=80):
        self.max_length = max_length
        self.current_line_length = 0

    def print(self, text_chunk):
        i = 0
        n = len(text_chunk)
        while i < n:
            start_index = i
            while i < n and text_chunk[i] not in ' \n': # Find end of word
                i += 1
            current_word = text_chunk[start_index:i]

            delimiter = ""
            if i < n: # If not end of chunk, we found a delimiter
                delimiter = text_chunk[i]
                i += 1 # Consume delimiter

            if current_word:
                needs_leading_space = (self.current_line_length > 0)

                # Case 1: Word itself is too long for a line (must be broken)
                if len(current_word) > self.max_length:
                    if needs_leading_space: # Newline if current line has content
                        sys.stdout.write('\n')
                        self.current_line_length = 0
                    for char_val in current_word: # Break the long word
                        if self.current_line_length >= self.max_length:
                            sys.stdout.write('\n')
                            self.current_line_length = 0
                        sys.stdout.write(char_val)
                        self.current_line_length += 1
                # Case 2: Word doesn't fit on current line (print on new line)
                elif self.current_line_length + (1 if needs_leading_space else 0) + len(current_word) > self.max_length:
                    sys.stdout.write('\n')
                    sys.stdout.write(current_word)
                    self.current_line_length = len(current_word)
                # Case 3: Word fits on current line
                else:
                    if needs_leading_space:
                        # Define punctuation that should not have a leading space
                        # when they form an entire "word" (token) following another word.
                        no_leading_space_punctuation = {
                            ",", ".", ";", ":", "!", "?",        # Standard sentence punctuation
                            ")", "]", "}",                     # Closing brackets
                            "'s", "'S", "'re", "'RE", "'ve", "'VE", # Common contractions
                            "'m", "'M", "'ll", "'LL", "'d", "'D",
                            "n't", "N'T",
                            "...", "…"                          # Ellipses
                        }
                        if current_word not in no_leading_space_punctuation:
                            sys.stdout.write(' ')
                            self.current_line_length += 1
                    sys.stdout.write(current_word)
                    self.current_line_length += len(current_word)

            if delimiter == '\n':
                sys.stdout.write('\n')
                self.current_line_length = 0
            elif delimiter == ' ':
                # If line is full and a space delimiter arrives, it implies a wrap.
                if self.current_line_length >= self.max_length:
                    sys.stdout.write('\n')
                    self.current_line_length = 0

        sys.stdout.flush()

# %%
# @title Formatted streaming example
from google.colab import ai

wrapper = LineWrapper()
for chunk in ai.generate_text('Give me a long winded description about the evolution of the Roman Empire.', model_name='google/gemini-2.0-flash', stream=True):
  wrapper.print(chunk)
# Out:
# The Roman Empire, a civilization whose tendrils of influence still grasp at our
# world today, didn't spring into existence fully formed like a miniature Minerva
# from Jupiter's brow. Instead, its rise was a slow, arduous, and often bloody
# process, a complex tapestry woven from threads of military conquest, political
# maneuvering, social upheaval, and cultural assimilation. To truly understand the
# Empire, one must trace its evolution from its humble beginnings as a small,
# unremarkable city-state in the Italian peninsula to the undisputed behemoth that
# dominated the Mediterranean world for centuries.
#
# Our story begins not with Emperors and legions, but with the semi-mythical
# founding of Rome in 753 BC, traditionally attributed to the twins Romulus and
# Remus. This nascent settlement, situated strategically on the Tiber River amidst
# seven hills, was initially ruled by a series of kings. These early monarchs,
# both Latin and Etruscan, laid the groundwork for Roman society, establishing
# foundational institutions, legal codes, and religious practices. This period,
# lasting for over two centuries, was characterized by steady growth and
# consolidation, as Rome gradually exerted its influence over neighboring Latin
# communities.
#
# However, the reign of kings eventually proved unsustainable. Corruption,
# tyranny, and a growing sense of Roman identity among the populace led to a
# dramatic power shift. In 509 BC, the last king, Tarquin the Proud, was
# overthrown, ushering in the era of the Roman Republic. This marked a pivotal
# moment, a conscious rejection of autocracy in favor of a complex system of
# governance designed to distribute power and prevent the concentration of
# authority in the hands of a single individual.
#
# The Republic's structure was multifaceted. Two annually elected consuls held
# executive power, leading the armies and administering the state. The Senate,
# composed of wealthy and influential patricians (aristocrats), served as an
# advisory body, wielding considerable influence over policy and finance.
# Assemblies, composed of various segments of the Roman citizenry, provided a
# platform for debate and legislation. This intricate system, though often plagued
# by internal conflicts and social inequalities between the patricians and
# plebeians (commoners), proved remarkably resilient and adaptable.
#
# The early Republic was characterized by near-constant warfare. Rome, driven by a
# potent combination of ambition, necessity, and a remarkable military prowess,
# embarked on a relentless campaign of expansion across Italy. Over centuries,
# they systematically subjugated or allied with the surrounding Latin tribes,
# Etruscan cities, and Samnite peoples, forging a unified Italian state under
# Roman leadership. This process was not without its setbacks, including the
# devastating sack of Rome by the Gauls in 390 BC, but the Romans consistently
# demonstrated an unwavering determination and a remarkable capacity for recovery.
#
# By the mid-3rd century BC, Rome had effectively conquered the Italian peninsula.
# However, this success brought them into direct conflict with Carthage, a
# powerful Phoenician city-state controlling vast swathes of North Africa and the
# Western Mediterranean. The resulting P unic Wars, a series of three brutal
# conflicts, tested Rome's strength to its limits. From the legendary campaigns of
# Hannibal, who invaded Italy with his elephants, to the climactic siege and
# destruction of Carthage, these wars were pivotal in shaping Roman identity and
# establishing Rome as the dominant power in the Mediterranean.
#
# Victory over Carthage paved the way for further expansion. Roman legions marched
# east, conquering Greece, Macedonia, and various Hellenistic kingdoms. They
# extended their reach westwards into Spain and Gaul (modern-day France). This
# period of unprecedented territorial expansion brought immense wealth and
# resources to Rome, but it also exacerbated existing social tensions and created
# new problems of governance.
#
# The influx of wealth and slaves led to the rise of powerful aristocratic
# families who amassed vast estates (latifundia), displacing small farmers and
# creating a large, landless proletariat in the cities. This growing inequality
# fueled social unrest and political instability. Figures like the Gracchi
# brothers attempted to address these issues through land reform, but their
# efforts were met with violent opposition from the entrenched elite.
#
# The late Republic was marked by a series of devastating civil wars. Powerful
# generals like Marius and Sulla used their legions to seize control of Rome,
# leading to periods of brutal proscription and political purges. The First
# Triumvirate, an informal alliance between Pompey, Crassus, and Julius Caesar,
# sought to stabilize the Republic, but ultimately collapsed into open conflict.
#
# Julius Caesar, a brilliant general and politician, emerged victorious from the
# civil war. He implemented a series of reforms aimed at addressing the Republic's
# problems, but his ambition and growing power aroused the suspicions of his
# opponents. In 44 BC, Caesar was assassinated by a group of senators who feared
# he was becoming a tyrant.
#
# Caesar's assassination plunged Rome into another round of civil war. His adopted
# son Octavian, along with Mark Antony and Lepidus, formed the Second Triumvirate
# to avenge Caesar's death and restore order. However, this alliance was
# short-lived. Octavian and Antony eventually clashed for control of Rome,
# culminating in the decisive Battle of Actium in 31 BC.
#
# Octavian emerged victorious from this final civil war. He skillfully navigated
# the treacherous political landscape, gradually consolidating power while
# maintaining the facade of the Republic. In 27 BC, he was granted the title of
# Augustus by the Senate, marking the official beginning of the Roman Empire.
#
# Augustus ushered in a period of relative peace and prosperity known as the Pax
# Romana (Roman Peace). He implemented significant reforms to the government, the
# military, and the economy, laying the foundation for the Empire's long-term
# stability. He expanded the Empire's borders, promoted trade and infrastructure
# development, and patronized the arts and sciences.
#
# The Roman Empire continued to expand and prosper under the reigns of Augustus'
# successors, the Julio-Claudian dynasty. Emperors like Tiberius, Caligula,
# Claudius, and Nero left their own marks on Roman history, some through their
# capable administration, others through their notorious excesses.
#
# The Flavian dynasty, which followed the Julio-Claudians, continued the trend of
# consolidating imperial power and expanding the Empire's reach. Vespasian, Titus,
# and Domitian oversaw the construction of the Colosseum, suppressed rebellions in
# Judea, and further strengthened the Empire's defenses.
#
# The 2nd century AD is often considered the Empire's golden age, a period marked
# by peace, prosperity, and strong leadership under the so -called "Five Good
# Emperors": Nerva, Trajan, Hadrian, Antoninus Pius, and Marcus Aurelius. These
# emperors were known for their wisdom, justice, and concern for the welfare of
# their subjects. They oversaw significant infrastructure projects, promoted trade
# and agriculture, and defended the Empire against external threats.
#
# However, the seeds of decline were already sown. The vastness of the Empire, the
# increasing bureaucracy, the reliance on slave labor, and the constant pressure
# from barbarian tribes along the frontiers began to strain the Empire's resources
# and its ability to govern effectively.
#
# The reign of Commodus, the son of Marcus Aurelius, marked a turning point. His
# incompetence and tyranny plunged the Empire into a period of instability and
# civil war. The 3rd century AD was a period of near-constant crisis, with rapid
# succession of emperors, barbarian invasions, economic collapse, and social
# unrest.
#
# To restore order and stability, Emperor Diocletian implemented radical reforms
# in the late 3rd century AD. He divided the Empire into two halves, the Western
# Roman Empire and the Eastern Roman Empire (later known as the Byzantine Empire),
# each ruled by an Emperor and a subordinate Caesar. This system, known as the
# Tetrarchy, was designed to improve governance and defense, but it ultimately
# proved unsustainable.
#
# Emperor Constantine I, who came to power in the early 4th century AD, reunited
# the Empire and made Christianity the official religion. He also moved the
# capital from Rome to Byzantium, which he renamed Constantinople. This shift
# reflected the growing importance of the Eastern Roman Empire and the decline of
# the Western Roman Empire.
#
# Despite Constantine's efforts, the Western Roman Empire continued to decline.
# Faced with internal divisions, economic problems, and relentless barbarian
# invasions, it gradually lost its territory and its ability to govern. In 476 AD,
# the last Western Roman Emperor, Romulus Augustulus, was deposed by a barbarian
# general, marking the traditional end of the Western Roman Empire.
#
# The Eastern Roman Empire, or Byzantine Empire, continued to thrive for another
# thousand years, preserving Roman traditions and culture in the East. It became a
# center of trade, learning, and artistic innovation, playing a crucial role in
# shaping the development of Europe and the Middle East.
#
# The evolution of the Roman Empire, therefore, is a story of transformation,
# adaptation, and ultimately, fragmentation. From its humble beginnings as a small
# city-state to its zenith as a vast and powerful empire, Rome left an indelible
# mark on the world. Its legacy can be seen in our laws, our languages, our
# political systems, our architecture, and our art. Understanding its rise and
# fall is crucial to understanding the history of Western civilization itself. It
# is a cautionary tale, a testament to the enduring power of human ambition, and a
# reminder that even the greatest empires are not immune to the forces of change
# and decay.
